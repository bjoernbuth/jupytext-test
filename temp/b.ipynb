# %%
1 + 1
# Out:
# 2

# %%
# import numpy and pandas and create 3 dataframes
import numpy as np
import pandas as pd

df1 = pd.DataFrame(np.random.randn(10, 5))
df2 = pd.DataFrame(np.random.randn(10, 5))
df3 = pd.DataFrame(np.random.randn(10, 5))

# %%
# display the first dataframe
df1
# Out:
#           0         1         2         3         4
# 0 -0.778331  0.070935 -1.290543 -0.928339 -0.348387
# 1 -0.317825 -0.483102  1.299874  1.677138  0.808422
# 2 -0.772225 -1.877727  0.464655 -1.781708 -0.448520
# 3 -0.131089 -0.641089  0.095481  0.750366  0.392096
# 4 -1.616262 -1.441880  0.242684  0.825220 -0.312869
# 5  0.777020 -0.856767 -1.652494  0.245731  1.487869
# 6  1.457510  0.527715  0.035986  0.480507 -1.276995
# 7  0.673203  1.858812 -0.838089 -1.288695  0.827617
# 8 -2.291517  0.931484 -1.673987 -0.437173  0.389388
# 9 -1.147708 -1.353762  0.321859  1.143645 -0.587702

# %%
# import matplotlib and plot the first dataframe
import matplotlib.pyplot as plt

df1.plot()
# Out:
# <AxesSubplot: >
